# %% [markdown]
# <a href="https://colab.research.google.com/github/Eriabinin777/Optimization-Class-Project/blob/main/optimization_project_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Набор данных содержит несколько параметров, которые считаются важными при подаче заявления на магистерские программы.
# Включенными параметрами являются :
# 1. GRE Scores ( out of 340 )
# 2. TOEFL Scores ( out of 120 )
# 3. University Rating ( out of 5 )
# 4. Statement of Purpose ( out of 5 )
# 5. Letter of Recommendation Strength ( out of 5 )
# 6. Undergraduate GPA ( out of 10 )
# 7. Research Experience ( either 0 or 1 )
# 8. Chance of Admit ( ranging from 0 to 1 )

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib.pyplot import matplotlib as plt

# %%
url = 'https://raw.githubusercontent.com/Eriabinin777/Optimization-Class-Project/main/adm_data.csv'
df = pd.read_csv(url)
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# # **Cтатистика**

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Chance of Admit      0.042336   0.802610     0.791594           0.711250
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138          0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391          0.802610
# ...

# %% [markdown]
# ## GRE Score

# %%
sns.distplot(df['GRE Score'], bins=30,color='black')
# Out:
# <ipython-input-103-84318df26389>:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='GRE Score', ylabel='Density'>

# %%
sns.histplot(df['GRE Score'], bins=25,color='black')
# Out:
# <Axes: xlabel='GRE Score', ylabel='Count'>

# %% [markdown]
# ## TOEFL Score

# %%
sns.distplot(df['TOEFL Score'], bins=30,color='black')
# Out:
# <ipython-input-24-41ef2ff62650>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TOEFL Score'], bins=30,color='black')
# <Axes: xlabel='TOEFL Score', ylabel='Density'>

# %%
sns.histplot(df['TOEFL Score'], bins=30,color='black')
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Count'>

# %% [markdown]
# ## University Rating

# %%
sns.distplot(df['University Rating'], bins=30,color='black')
# Out:
# <ipython-input-26-f2ac86963bc1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['University Rating'], bins=30,color='black')
# <Axes: xlabel='University Rating', ylabel='Density'>

# %%
sns.histplot(df['University Rating'], bins=30,color='black')
# Out:
# <Axes: xlabel='University Rating', ylabel='Count'>

# %% [markdown]
# ## SOP

# %%
sns.distplot(df['SOP'], bins=30,color='black')
# Out:
# <ipython-input-25-4feccae50808>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SOP'], bins=30,color='black')
# <Axes: xlabel='SOP', ylabel='Density'>

# %%
sns.histplot(df['SOP'], bins=30,color='black')
# Out:
# <Axes: xlabel='SOP', ylabel='Count'>

# %% [markdown]
# ## LOR

# %%
sns.distplot(df['LOR '], bins=30,color='black')
# Out:
# <ipython-input-29-94c315ce9d11>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LOR '], bins=30,color='black')
# <Axes: xlabel='LOR ', ylabel='Density'>

# %%
sns.histplot(df['LOR '], bins=30,color='black')
# Out:
# <Axes: xlabel='LOR ', ylabel='Count'>

# %% [markdown]
# ## CGPA

# %%
sns.distplot(df['CGPA'], bins=30,color='black')
# Out:
# <ipython-input-31-ef0dc12a083c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CGPA'], bins=30,color='black')
# <Axes: xlabel='CGPA', ylabel='Density'>

# %%
sns.histplot(df['CGPA'], bins=30,color='black')
# Out:
# <Axes: xlabel='CGPA', ylabel='Count'>

# %% [markdown]
# ## Research

# %%
sns.distplot(df['Research'], bins=30,color='black')
# Out:
# <ipython-input-33-bef316980af3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Research'], bins=30,color='black')
# <Axes: xlabel='Research', ylabel='Density'>

# %%
sns.histplot(df['Research'], bins=30,color='black')
# Out:
# <Axes: xlabel='Research', ylabel='Count'>

# %% [markdown]
# ## Chance of Admit

# %%
sns.distplot(df['Chance of Admit '], bins=30,color='black')
# Out:
# <ipython-input-35-5f8bb0533194>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Chance of Admit '], bins=30,color='black')
# <Axes: xlabel='Chance of Admit ', ylabel='Density'>

# %%
sns.histplot(df['Chance of Admit '], bins=30,color='black')
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='Count'>

# %% [markdown]
# # **Двумерный анализ**

# %% [markdown]
# ## GRE Score

# %%
sns.scatterplot(x = df['GRE Score'], y = df['TOEFL Score'])
# Out:
# <Axes: xlabel='GRE Score', ylabel='TOEFL Score'>

# %%
sns.scatterplot(x=df['GRE Score'],y=df['University Rating'])
# Out:
# <Axes: xlabel='GRE Score', ylabel='University Rating'>

# %%
sns.scatterplot(x=df['GRE Score'],y=df['SOP'])
# Out:
# <Axes: xlabel='GRE Score', ylabel='SOP'>

# %%
sns.scatterplot(x=df['GRE Score'],y=df['LOR '])
# Out:
# <Axes: xlabel='GRE Score', ylabel='LOR '>

# %%
sns.scatterplot(x=df['GRE Score'],y=df['CGPA'])
# Out:
# <Axes: xlabel='GRE Score', ylabel='CGPA'>

# %%
sns.scatterplot(x=df['GRE Score'],y=df['Research'])
# Out:
# <Axes: xlabel='GRE Score', ylabel='Research'>

# %%
sns.lmplot(y='Research', x='GRE Score', data=df, logistic=True)

# %%
sns.scatterplot(x=df['GRE Score'],y=df['Chance of Admit '])
# Out:
# <Axes: xlabel='GRE Score', ylabel='Chance of Admit '>

# %%
sns.regplot(y='Chance of Admit ', x='GRE Score', data=df, scatter=True)
# Out:
# <Axes: xlabel='GRE Score', ylabel='Chance of Admit '>

# %%
sns.lmplot(y='Chance of Admit ', x='GRE Score', data=df, lowess=True)

# %% [markdown]
# ## TOEFL Score

# %%
sns.scatterplot(x=df['TOEFL Score'],y=df['University Rating'])
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='University Rating'>

# %%
sns.scatterplot(x=df['TOEFL Score'],y=df['GRE Score'])
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='GRE Score'>

# %%
sns.scatterplot(x=df['TOEFL Score'],y=df['SOP'])
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='SOP'>

# %%
sns.scatterplot(x=df['TOEFL Score'],y=df['LOR '])
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='LOR '>

# %%
sns.scatterplot(x=df['TOEFL Score'],y=df['CGPA'])
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='CGPA'>

# %%
sns.scatterplot(x=df['TOEFL Score'],y=df['Research'])
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Research'>

# %%
sns.scatterplot(x=df['TOEFL Score'],y=df['Chance of Admit '])
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Chance of Admit '>

# %%
sns.regplot(y='Chance of Admit ', x='TOEFL Score', data=df, scatter=True)
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Chance of Admit '>

# %%
sns.lmplot(y='Chance of Admit ', x='TOEFL Score', data=df, lowess=True)

# %% [markdown]
# ## University Rating

# %%
sns.scatterplot(x=df['University Rating'],y=df['TOEFL Score'])
# Out:
# <Axes: xlabel='University Rating', ylabel='TOEFL Score'>

# %%
sns.regplot(y='TOEFL Score', x='University Rating', data=df, scatter=True)
# Out:
# <Axes: xlabel='University Rating', ylabel='TOEFL Score'>

# %%
sns.scatterplot(x=df['University Rating'],y=df['GRE Score'])
# Out:
# <Axes: xlabel='University Rating', ylabel='GRE Score'>

# %%
sns.regplot(y='GRE Score', x='University Rating', data=df, scatter=True)
# Out:
# <Axes: xlabel='University Rating', ylabel='GRE Score'>

# %%
sns.scatterplot(x=df['University Rating'],y=df['SOP'])
# Out:
# <Axes: xlabel='University Rating', ylabel='SOP'>

# %%
sns.scatterplot(x=df['University Rating'],y=df['LOR '])
# Out:
# <Axes: xlabel='University Rating', ylabel='LOR '>

# %%
sns.scatterplot(x=df['University Rating'],y=df['CGPA'])
# Out:
# <Axes: xlabel='University Rating', ylabel='CGPA'>

# %%
sns.regplot(y='CGPA', x='University Rating', data=df, scatter=True)
# Out:
# <Axes: xlabel='University Rating', ylabel='CGPA'>

# %%
sns.scatterplot(x=df['University Rating'],y=df['Research'])
# Out:
# <Axes: xlabel='University Rating', ylabel='Research'>

# %%
sns.scatterplot(x=df['University Rating'],y=df['Chance of Admit '])
# Out:
# <Axes: xlabel='University Rating', ylabel='Chance of Admit '>

# %%
sns.regplot(y='Chance of Admit ', x='University Rating', data=df, scatter=True)
# Out:
# <Axes: xlabel='University Rating', ylabel='Chance of Admit '>

# %% [markdown]
# ## SOP

# %%
sns.scatterplot(x=df['SOP'],y=df['TOEFL Score'])
# Out:
# <Axes: xlabel='SOP', ylabel='TOEFL Score'>

# %%
sns.scatterplot(x=df['SOP'],y=df['University Rating'])
# Out:
# <Axes: xlabel='SOP', ylabel='University Rating'>

# %%
sns.scatterplot(x=df['SOP'],y=df['GRE Score'])
# Out:
# <Axes: xlabel='SOP', ylabel='GRE Score'>

# %%
sns.scatterplot(x=df['SOP'],y=df['LOR '])
# Out:
# <Axes: xlabel='SOP', ylabel='LOR '>

# %%
sns.scatterplot(x=df['SOP'],y=df['CGPA'])
# Out:
# <Axes: xlabel='SOP', ylabel='CGPA'>

# %%
sns.scatterplot(x=df['SOP'],y=df['Research'])
# Out:
# <Axes: xlabel='SOP', ylabel='Research'>

# %%
sns.scatterplot(x=df['SOP'],y=df['Chance of Admit '])
# Out:
# <Axes: xlabel='SOP', ylabel='Chance of Admit '>

# %% [markdown]
# ## LOR

# %%
sns.scatterplot(x=df['LOR '],y=df['TOEFL Score'])
# Out:
# <Axes: xlabel='LOR ', ylabel='TOEFL Score'>

# %%
sns.scatterplot(x=df['LOR '],y=df['University Rating'])
# Out:
# <Axes: xlabel='LOR ', ylabel='University Rating'>

# %%
sns.scatterplot(x=df['LOR '],y=df['SOP'])
# Out:
# <Axes: xlabel='LOR ', ylabel='SOP'>

# %%
sns.scatterplot(x=df['LOR '],y=df['GRE Score'])
# Out:
# <Axes: xlabel='LOR ', ylabel='GRE Score'>

# %%
sns.scatterplot(x=df['LOR '],y=df['CGPA'])
# Out:
# <Axes: xlabel='LOR ', ylabel='CGPA'>

# %%
sns.scatterplot(x=df['LOR '],y=df['Research'])
# Out:
# <Axes: xlabel='LOR ', ylabel='Research'>

# %%
sns.scatterplot(x=df['LOR '],y=df['Chance of Admit '])
# Out:
# <Axes: xlabel='LOR ', ylabel='Chance of Admit '>

# %% [markdown]
# ## CGPA

# %%
sns.scatterplot(x=df['CGPA'],y=df['TOEFL Score'])
# Out:
# <Axes: xlabel='CGPA', ylabel='TOEFL Score'>

# %%
sns.scatterplot(x=df['CGPA'],y=df['University Rating'])
# Out:
# <Axes: xlabel='CGPA', ylabel='University Rating'>

# %%
sns.scatterplot(x=df['CGPA'],y=df['SOP'])
# Out:
# <Axes: xlabel='CGPA', ylabel='SOP'>

# %%
sns.scatterplot(x=df['CGPA'],y=df['LOR '])
# Out:
# <Axes: xlabel='CGPA', ylabel='LOR '>

# %%
sns.scatterplot(x=df['CGPA'],y=df['GRE Score'])
# Out:
# <Axes: xlabel='CGPA', ylabel='GRE Score'>

# %%
sns.scatterplot(x=df['CGPA'],y=df['Research'])
# Out:
# <Axes: xlabel='CGPA', ylabel='Research'>

# %%
sns.scatterplot(x=df['CGPA'],y=df['Chance of Admit '])
# Out:
# <Axes: xlabel='CGPA', ylabel='Chance of Admit '>

# %%
sns.regplot(y='Chance of Admit ', x='CGPA', data=df, scatter=True)
# Out:
# <Axes: xlabel='CGPA', ylabel='Chance of Admit '>

# %%
sns.lmplot(y='Chance of Admit ', x='CGPA', data=df, lowess=True)

# %% [markdown]
# ## Research

# %%
sns.scatterplot(x=df['Research'],y=df['TOEFL Score'])
# Out:
# <Axes: xlabel='Research', ylabel='TOEFL Score'>

# %%
sns.scatterplot(x=df['Research'],y=df['University Rating'])
# Out:
# <Axes: xlabel='Research', ylabel='University Rating'>

# %%
sns.scatterplot(x=df['Research'],y=df['SOP'])
# Out:
# <Axes: xlabel='Research', ylabel='SOP'>

# %%
sns.scatterplot(x=df['Research'],y=df['LOR '])
# Out:
# <Axes: xlabel='Research', ylabel='LOR '>

# %%
sns.scatterplot(x=df['Research'],y=df['CGPA'])
# Out:
# <Axes: xlabel='Research', ylabel='CGPA'>

# %%
sns.scatterplot(x=df['Research'],y=df['GRE Score'])
# Out:
# <Axes: xlabel='Research', ylabel='GRE Score'>

# %%
sns.scatterplot(x=df['Research'],y=df['Chance of Admit '])
# Out:
# <Axes: xlabel='Research', ylabel='Chance of Admit '>

# %% [markdown]
# ## Chance of Admit

# %%
sns.scatterplot(x=df['Chance of Admit '],y=df['TOEFL Score'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='TOEFL Score'>

# %%
sns.scatterplot(x=df['Chance of Admit '],y=df['University Rating'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='University Rating'>

# %%
sns.scatterplot(x=df['Chance of Admit '],y=df['SOP'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='SOP'>

# %%
sns.scatterplot(x=df['Chance of Admit '],y=df['LOR '])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='LOR '>

# %%
sns.scatterplot(x=df['Chance of Admit '],y=df['CGPA'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='CGPA'>

# %%
sns.scatterplot(x=df['Chance of Admit '],y=df['Research'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='Research'>

# %%
sns.scatterplot(x=df['Chance of Admit '],y=df['GRE Score'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='GRE Score'>

# %%
sns.regplot(x='Chance of Admit ', y='GRE Score', data=df, scatter=True)
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='GRE Score'>

# %%
sns.lmplot(x='Chance of Admit ', y='GRE Score', data=df, lowess=True)

# %%
sns.lmplot(x='Chance of Admit ', y='Research', data=df, logistic=True)
